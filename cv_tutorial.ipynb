# %%
import cv2 as cv
from cv2 import samples
import numpy as np
import sys
from PIL.Image import Image

# %%
img = cv.imread('majestic.jpeg')
img = cv.blur(img,(25,25))
img_x = 750
img_y = 1000
img = cv.resize(img,(img_x,img_y),interpolation = cv.INTER_LINEAR)
Image.fromarray(img)
# Out:
# <PIL.Image.Image image mode=RGB size=750x1000>
